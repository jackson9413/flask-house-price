# %%
# load the libraries
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read csv file
df  = pd.read_csv('kc_house_data.csv')

# top 5
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# dimensions
df.shape
# Out:
# (21613, 21)

# %%
# data types
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# summary for the numerical variables
df.describe(include = [np.number])
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# draw a pairplot
# exclude id, date, zip code, latitude, longitude 
# sns.pairplot(df, 
#              vars = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 
#                      'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 
#                      'yr_built', 'yr_renovated', 'sqft_living15', 'sqft_lot15'])

# %%
# exclude id, date, zip code, latitude, longitude columns
#df = df.drop(['id', 'date', 'zipcode', 'lat', 'long'], axis = 1)

# %%
# draw a heatmap to show the correlation between other columns and the price column
# exclude id, date, zip code, latitude, longitude
# sort by correlation with price
# show half of the heatmap
# plt.figure(figsize=(20,20))
# sns.heatmap(df.drop(['id', 'date', 'zipcode', 'lat', 'long'], axis = 1).corr(), annot=True, cmap='coolwarm', center=0)

# %%
# columns whose correlation with price larger than 0.3
df.drop(['id', 'date', 'zipcode', 'lat', 'long'], axis = 1).corr().price[df.drop(['id', 'date', 'zipcode', 'lat', 'long'], axis = 1).corr().price > 0.3]
# Out:
# price            1.000000
# bedrooms         0.308350
# bathrooms        0.525138
# sqft_living      0.702035
# view             0.397293
# grade            0.667434
# sqft_above       0.605567
# sqft_basement    0.323816
# sqft_living15    0.585379
# Name: price, dtype: float64

# %%
# draw a heat map to show the correlation between the columns whose correlation with price larger than 0.3
# SHOW THIS PLOT
# plt.figure(figsize=(20,20))
# sns.heatmap(df[["price", "bedrooms", "bathrooms", "sqft_living", "sqft_above", "sqft_basement"]].corr(), annot=True, cmap='coolwarm', center=0)

# %%
# use plotly to draw a heatmap
# set figure size
# show the plot
import plotly.express as px
fig = px.imshow(df[["price", "bedrooms", "bathrooms", "sqft_living", "sqft_above", "sqft_basement"]].corr(), height=800, width=800)
fig.show()

# %%
# plt.figure(figsize=(10,10))
# sns.heatmap(df.drop(['id', 'date', 'zipcode', 'lat', 'long'], axis = 1).corr().loc[['price', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'bathrooms', 'view', 'sqft_basement', 'bedrooms']], 
#             annot=True, cmap='coolwarm', center=0)

# %%
# draw a pairplot for the columns whose correlation with price larger than 0.3

# sns.pairplot(df, vars = ['price', 'bedrooms',  'bathrooms', 'sqft_living', 'view', 'grade', 'sqft_above', 'sqft_basement'])

# %%
# show the relationship between price and sqft_living, sqft_above, sqft_basement 
# SHOW THIS PLOT
plt.figure(figsize=(10,10))
sns.scatterplot(x = 'sqft_living', y = 'price', data = df)
plt.figure(figsize=(10,10))
sns.scatterplot(x = 'sqft_above', y = 'price', data = df)
plt.figure(figsize=(10,10))
sns.scatterplot(x = 'sqft_basement', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='sqft_basement', ylabel='price'>

# %%
# use plotly to show the relationship between price and sqft_living, sqft_above, sqft_basement
# set figure size
# show the plot
fig = px.scatter(df, x = 'sqft_living', y = 'price', height=800, width=800)
fig.show()

# %%
# zip code unique count
df['zipcode'].nunique()
# Out:
# 70

# %%
# draw a plot to show the relationship between zip code and price
plt.figure(figsize=(20,10))
sns.boxplot(x = 'zipcode', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='zipcode', ylabel='price'>

# %%
# zip code with the top 10 average price
df.groupby('zipcode').price.mean().nlargest(10)
# Out:
# zipcode
# 98039    2.160607e+06
# 98004    1.355927e+06
# 98040    1.194230e+06
# 98112    1.095499e+06
# 98102    9.012583e+05
# 98109    8.796236e+05
# 98105    8.628252e+05
# 98006    8.596848e+05
# 98119    8.494480e+05
# 98005    8.101649e+05
# Name: price, dtype: float64

# %%
# draw a box plot to show number of bedrooms and price
plt.figure(figsize=(20,10))
sns.boxplot(x = 'bedrooms', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
# group by number of bedrooms and count the number of houses
# sort by number of houses in descending order 
df.groupby('bedrooms').size().sort_values(ascending = False)
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# dtype: int64

# %% [markdown]
# Most of the houses have one to 6 bedrooms.

# %%
# draw a box plot to shown houses with 1 to 6 bedrooms and price
plt.figure(figsize=(20,10))
sns.boxplot(x = 'bedrooms', y = 'price', data = df[df['bedrooms'] <= 6])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
# use plotly to draw a box plot to show the relationship between number of bedrooms and price
# set figure size
# show the plot
fig = px.box(df[df['bedrooms'] <= 6], x="bedrooms", y="price", height=800, width=800)
fig.show()

# %%
# draw a box plot to show number of bathrooms and price
plt.figure(figsize=(20,10))
sns.boxplot(x = 'bathrooms', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
# group by number of bathrooms and count the number of houses
# sort by number of houses in descending order
df.groupby('bathrooms').size().sort_values(ascending = False)
# Out:
# bathrooms
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 0.00      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 6.25       2
# 6.50       2
# 6.75       2
# 8.00       2
# 7.50       1
# 7.75       1
# dtype: int64

# %% [markdown]
# Most of the houses have 1 to 4 bathrooms.

# %%
# draw a box plot to shown houses with 1 to 4 bathrooms and price
# SHOW THIS PLOT
plt.figure(figsize=(20,10))
sns.boxplot(x = 'bathrooms', y = 'price', data = df[df['bathrooms'] <= 4])
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
# draw a box plot to show the relationship between grade and price
# display the underlying data points
plt.figure(figsize=(20,10))
sns.boxplot(x = 'grade', y = 'price', data = df)
#sns.swarmplot(x = 'grade', y = 'price', data = df, color = 'k', alpha = 0.5)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
# group by grade and count the number of houses
# sort by number of houses in descending order
df.groupby('grade').size().sort_values(ascending = False)
# Out:
# grade
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# dtype: int64

# %%
# draw a box plot to show the relationship between grade and price
plt.figure(figsize=(20,10))
sns.violinplot(x = 'grade', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %% [markdown]
# most of the houses have grade from 5 to 12.

# %%
# show the relationship between views and price
plt.figure(figsize=(20,10))
sns.boxplot(x = 'view', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='view', ylabel='price'>

# %%
# draw a plot to show year built and price
plt.figure(figsize=(20,10))
sns.scatterplot(x = 'yr_built', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='yr_built', ylabel='price'>

# %%
# group by year built and average price
# draw a plot to show the relationship between year built and average price
plt.figure(figsize=(20,10))
df.groupby('yr_built').price.mean().plot()
# Out:
# <AxesSubplot:xlabel='yr_built'>

# %%
# group by year built and count the number of houses
# draw a plot to show the relationship between year built and number of houses
plt.figure(figsize=(20,10))
df.groupby('yr_built').size().plot()
# Out:
# <AxesSubplot:xlabel='yr_built'>

# %%
# include bedrooms, bathrooms, sqft_living, sqft_above, sqft_basement, price
df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_above', 'sqft_basement', 'price']].head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_above  sqft_basement     price
# 0         3       1.00         1180        1180              0  221900.0
# 1         3       2.25         2570        2170            400  538000.0
# 2         2       1.00          770         770              0  180000.0
# 3         4       3.00         1960        1050            910  604000.0
# 4         3       2.00         1680        1680              0  510000.0

# %%
# standardize the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['sqft_living', 'sqft_above', 'sqft_basement', 'price']] = scaler.fit_transform(df[['sqft_living', 'sqft_above', 'sqft_basement', 'price']])

# %%
# top 5
df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_above', 'sqft_basement', 'price']].head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_above  sqft_basement     price
# 0         3       1.00    -0.979835   -0.734708      -0.658681 -0.866717
# 1         3       2.25     0.533634    0.460841       0.245141 -0.005688
# 2         2       1.00    -1.426254   -1.229834      -0.658681 -0.980849
# 3         4       3.00    -0.130550   -0.891699       1.397515  0.174090
# 4         3       2.00    -0.435422   -0.130895      -0.658681 -0.081958

# %%
# split the data into training and testing
# set seed
from sklearn.model_selection import train_test_split
X = df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_above', 'sqft_basement']]
y = df['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
# fit a linear regression model
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# evaluate the model
from sklearn.metrics import mean_squared_error
y_pred = lm.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 0.48792530012032204

# %%
# R squared
lm.score(X_test, y_test)
# Out:
# 0.534341233795852
